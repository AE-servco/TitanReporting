# %%
import sys
sys.path.insert(0, "../app/modules")
from datetime import datetime, date, time
import pandas as pd
from servicetitan_api_client import ServiceTitanClient

from google.cloud import secretmanager
import data

# %%
tenants = ['alphabravo', 'foxtrotwhiskey', 'sierradelta', 'victortango', 'echozulu']

# %%
def get_secret(secret_id, project_id="servco1", version_id="latest"):
    client = secretmanager.SecretManagerServiceClient()
    name = f"projects/{project_id}/secrets/{secret_id}/versions/{version_id}"
    response = client.access_secret_version(request={"name": name})
    secret_payload = response.payload.data.decode("UTF-8")
    return secret_payload

# %%
clients = {tenant: ServiceTitanClient(
                app_key=get_secret("ST_app_key_tester"), 
                app_guid=get_secret("ST_servco_integrations_guid"), 
                tenant=get_secret(f"ST_tenant_id_{tenant}"), 
                client_id=get_secret(f"ST_client_id_{tenant}"), 
                client_secret=get_secret(f"ST_client_secret_{tenant}"), 
                environment="production"
            ) 
           for tenant in tenants}

# %%
def get_all_payment_types_used(tenant):
    client = clients[tenant]
    url = client.build_url('accounting', 'payments')
    output = set()
    page = 1
    params = {'page': page, 'pageSize': 1000, 'includeTotal': 'true'}

    while True:
        print(page)
        params['page'] = page
        try:
            resp = client.get(url, params=params)
        except Exception:
            break        
        if not isinstance(resp, dict):
            break
        print(resp['totalCount'])
        data = resp.get("data") or []
        for payment in data:
            output.add(payment.get('type', ''))
        has_more = resp.get("hasMore")
        if has_more:
            page += 1
            continue
        break
    return output

# %%
alltypes = set()
for tenant in tenants:
    print(tenant)
    types = get_all_payment_types_used(tenant)
    alltypes.update(types)
alltypes
# Out:
# alphabravo
# 1
# 24235
# 2
# 24235
# 3
# 24235
# 4
# 24235
# 5
# 24235
# 6
# 24235
# 7
# 24235
# 8
# 24235
# 9
# 24235
# 10
# 24235
# 11
# 24235
# 12
# 24235
# 13
# 24235
# 14
# 24235
# 15
# 24235
# 16
# 24235
# 17
# 24235
# 18
# 24235
# 19
# 24235
# 20
# 24235
# 21
# 24235
# 22
# 24235
# 23
# 24235
# 24
# 24235
# 25
# 24235
# foxtrotwhiskey
# 1
# 982
# sierradelta
# 1
# 566
# victortango
# 1
# 6848
# 2
# 6848
# 3
# 6848
# 4
# 6848
# 5
# 6848
# 6
# 6848
# 7
# 6848
# echozulu
# 1
# 21832
# 2
# 21832
# 3
# 21832
# 4
# 21832
# 5
# 21832
# 6
# 21832
# 7
# 21832
# 8
# 21833
# 9
# 21833
# 10
# 21833
# 11
# 21833
# 12
# 21833
# 13
# 21833
# 14
# 21833
# 15
# 21833
# 16
# 21833
# 17
# 21833
# 18
# 21833
# 19
# 21833
# 20
# 21833
# 21
# 21833
# 22
# 21833
# {'AMEX',
#  'Applied Payment for AR',
#  'Cash',
#  'Check',
#  'Credit Card',
#  'EFT/Bank Transfer',
#  'Humm - Finance Fee',
#  'Humm Payment Plan',
#  'Imported Default Credit Card',
#  'MasterCard',
#  'Payment Plan',
#  'Payment Plan - Fee',
#  'Processed in ServiceM8',
#  'Refund (check)',
#  'Refund (credit card)',
#  'Visa'}

# %%
options = {
    'totalGreater': 6439,
    'paidOnAfter': '2025-10-25',
    'paidOnBefore': '2025-11-03'
}

# %%
dfs = {}
for state, ds in data_services.items():
    dfs[state] = pd.DataFrame(ds.get_api_data('accounting', 'payments', options=options))

# %%
for state, ds in data_services.items():
    dfs[state]["job_num_applied_to"] = dfs[state].apply(lambda row: row["appliedTo"][0]['appliedToReferenceNumber'], axis=1)

# %%
dfs['NSW'][['job_num_applied_to', 'total']]
# Out:
#   job_num_applied_to     total
# 0             300067   6745.86
# 1             100356  16051.86
# 2             300071  10000.00

# %%
dfs['WA'][['job_num_applied_to', 'total']]
# Out:
#   job_num_applied_to     total
# 0             100194  18070.86

# %% [markdown]
# ## Estimates

# %%
est_options = {
    'totalGreater': 6439,
    'createdOnOrAfter': '2025-10-25',
    'createdBefore': '2025-11-02'
}

# %%
est_dfs = {}
for state, ds in data_services.items():
    est_dfs[state] = pd.DataFrame(ds.get_api_data('sales', 'estimates', options=est_options))

# %%
for state, ds in data_services.items():
    est_dfs[state]["descriptions"] = est_dfs[state].apply(lambda row: row["items"]['description'], axis=1)

# %%
est_dfs['NSW'][['jobNumber', 'status', 'subtotal', 'createdOn','items']].sort_values(by=['status','createdOn'])
# Out:
#    jobNumber status  subtotal                     createdOn  \
# 0     100360   Open   8614.00      2025-10-25T00:03:05.293Z
# 1     100387   Open   6841.00  2025-10-27T00:35:57.4964955Z
# 3     300017   Open  18161.00      2025-10-27T04:25:08.767Z
# 6     300021   Open  14861.00      2025-10-27T06:34:49.506Z
# 11    300014   Open  11353.00      2025-10-28T01:52:08.687Z
# 13    300000   Open  14641.00  2025-10-28T02:35:43.8327908Z
# 10    100393   Open  35025.00      2025-10-28T03:35:07.533Z
# 9     300058   Open  18161.00      2025-10-28T04:33:36.634Z
# 14    300078   Open  17954.64      2025-10-28T05:15:29.416Z
# 16    300049   Open  15076.00  2025-10-28T06:01:10.0169759Z
# 18    300107   Open  16344.90       2025-10-29T02:50:13.19Z
# 20    300167   Open  17894.00      2025-10-30T01:41:04.119Z
# 22    300171   Open   8214.00  2025-10-30T04:23:37.9211729Z
# 23    300200   Open  14614.00      2025-10-30T06:21:35.795Z
# 26    300188   Open  11911.00      2025-10-30T22:18:16.636Z
# 25    300214   Open   7076.00   2025-10-30T22:19:23.076397Z
# 24    300207   Open  16214.00      2025-10-31T06:05:56.786Z
# 5     300025   Sold   8214.00    2025-10-27T02:49:42.18079Z
# 2     100256   Sold  11676.00      2025-10-27T03:21:49.873Z
# 4     100374   Sold   9192.00  2025-10-27T04:06:50.0268142Z
# 8     100397   Sold  16814.00      2025-10-27T23:09:21.223Z
# 7     100370   Sold   7803.30      2025-10-28T02:10:31.369Z
# 12    300068   Sold   8295.00  2025-10-28T02:22:30.4413966Z
# 15    300067   Sold   6814.00  2025-10-28T05:21:54.2578369Z
# 17    300102   Sold  18161.00  2025-10-28T22:30:13.9006514Z
# 19    300149   Sold   7766.10  2025-10-29T21:24:38.7568775Z
# 21    300161   Sold  16344.90  2025-10-30T03:29:42.0980733Z
# 27    300217   Sold  17023.00      2025-10-31T00:05:24.704Z
# 28    300232   Sold  16344.90  2025-10-31T02:37:24.6967368Z
#
#                                                 items
# 0   [{'id': 143457174, 'sku': {'id': 116214490, 'n...
# 1   [{'id': 143481046, 'sku': {'id': 116215117, 'n...
# 3   [{'id': 143493775, 'sku': {'id': 116215566, 'n...
# 6   [{'id': 143493811, 'sku': {'id': 116214496, 'n...
# 11  [{'id': 143520050, 'sku': {'id': 116215566, 'n...
# 13  [{'id': 143533002, 'sku': {'id': 116215566, 'n...
# 10  [{'id': 143520069, 'sku': {'id': 116214237, 'n...
# 9   [{'id': 143522733, 'sku': {'id': 116214652, 'n...
# 14  [{'id': 143610340, 'sku': {'id': 116215566, 'n...
# 16  [{'id': 143613089, 'sku': {'id': 116214508, 'n...
# 18  [{'id': 143636677, 'sku': {'id': 116214646, 'n...
# 20  [{'id': 143663558, 'sku': {'id': 116215572, 'n...
# 22  [{'id': 143677307, 'sku': {'id': 116214354, 'n...
# 23  [{'id': 143661637, 'sku': {'id': 116214475, 'n...
# 26  [{'id': 143690399, 'sku': {'id': 116214208, 'n...
# 25  [{'id': 143688474, 'sku': {'id': 116214493, 'n...
# 24  [{'id': 143696740, 'sku': {'id': 116215572, 'n...
# 5   [{'id': 143490092, 'sku': {'id': 116215199, 'n...
# 2   [{'id': 143494026, 'sku': {'id': 116215566, 'n...
# 4   [{'id': 143488244, 'sku': {'id': 116214490, 'n...
# 8   [{'id': 143526021, 'sku': {'id': 116214481, 'n...
# 7   [{'id': 143521571, 'sku': {'id': 116213947, 'n...
# 12  [{'id': 143532012, 'sku': {'id': 116214249, 'n...
# 15  [{'id': 143610893, 'sku': {'id': 116215280, 'n...
# 17  [{'id': 143624981, 'sku': {'id': 116215566, 'n...
# 19  [{'id': 143651591, 'sku': {'id': 61455469, 'na...
# 21  [{'id': 143677338, 'sku': {'id': 61455469, 'na...
# 27  [{'id': 143686214, 'sku': {'id': 116287613, 'n...
# 28  [{'id': 143705286, 'sku': {'id': 116215566, 'n...

# %%
est_dfs['NSW'].iloc[5]['items']
# Out:
# [{'id': 143490092,
#   'sku': {'id': 116215199,
#    'name': 'T-NEW-212 1',
#    'displayName': 'RELOCATION OF EXISTING 20MM WATER METER UP TO 1.5M FROM EXISTING LOCATION',
#    'type': 'Service',
#    'soldHours': 0.0,
#    'generalLedgerAccountId': 81,
#    'generalLedgerAccountName': 'Sales Income',
#    'modifiedOn': '2025-09-10T02:42:12.9073808Z'},
#   'skuAccount': 'Sales Income',
#   'description': 'RELOCATION OF EXISTING 20MM WATER METER UP TO 1.5M FROM EXISTING LOCATION<br><br>Obtain service location diagram (if required) <br> Obtain dial before dig (if required) <br> Set up safe working area <br> Dig &amp; excavate ground area up to 1.5M <br> Expose main water service inlet connecting to main water meter <br> Expose main water service outlet connecting to property up to 1.5M <br> Disconnect main meter unions <br> Disconnect &amp; removal of main water meter <br> Disconnect &amp; removal of existing main water meter unions <br> Disconnect &amp; removal of existing brass fittings <br> Disconnect &amp; removal of main water meter isolation valve <br> Cut &amp; removal of existing section of main water service inlet under live pressure <br> Cut &amp; removal of existing section of main water service outlet <br> Clean existing water service live under pressure <br> Prepare main water service inlet for new live connection <br> Prepare main water service outlet for new connection <br> Supply &amp; install new main meter emergency isolation valve <br> Supply &amp; install section of new copper water service to main water meter inlet UP TO 1.5M - RELOCATION<br> Supply &amp; install section of new copper water service to main meter outlet<br> Supply &amp; install new brass fittings <br> Supply &amp; install new B-press fittings <br> Supply &amp; install new main meter emergency isolation valve <br> Supply &amp; install new main meter union kit <br> Supply &amp; install new main meter gasket kit <br> Reinstall main water meter in new location <br> Use of specialist crimping tool <br> Crimp new water service <br> Reinstate water supply to property <br> Conduct pressure test on service to ensure no further leaks <br> Test &amp; commission installation <br> Back fill worked area <br> Removal of trade waste<br>PLEASE NOTE IF FURTHER WORK REQUIRED OTHER THAN QUOTED WORKS ADDITIONAL COSTS WILL APPLY',
#   'membershipTypeId': None,
#   'qty': 1.0,
#   'unitRate': 8214.0,
#   'total': 8214.0,
#   'unitCost': 0.0,
#   'totalCost': 0.0,
#   'itemGroupName': None,
#   'itemGroupRootId': None,
#   'createdOn': '2025-10-27T02:52:34.4454919Z',
#   'modifiedOn': '2025-10-27T22:49:11.495247Z',
#   'chargeable': None,
#   'invoiceItemId': 143490106,
#   'budgetCodeId': None}]

# %% [markdown]
# ## Invoices

# %%
inv_options = {
    'totalGreater': 6439,
    'createdOnOrAfter': '2025-10-01',
    'createdBefore': '2025-11-02'
}

# %%
inv_dfs = {}
for state, ds in data_services.items():
    inv_dfs[state] = pd.DataFrame(ds.get_api_data('accounting', 'invoices', options=inv_options))

# %%
for state, ds in data_services.items():
    inv_dfs[state]["jobNumber"] = inv_dfs[state].apply(lambda row: row["job"]['number'], axis=1)
    inv_dfs[state]["balance"] = inv_dfs[state].apply(lambda row: float(row["balance"]), axis=1)

# %%
inv_dfs['WA'][inv_dfs['NSW']['balance']>0][['jobNumber','balance']]
# Out:
# C:\Users\AlbieEwins\AppData\Local\Temp\ipykernel_16128\3522126881.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inv_dfs['WA'][inv_dfs['NSW']['balance']>0][['jobNumber','balance']]
#    jobNumber   balance
# 9     500094   6422.65
# 11    500143  12168.42

# %%
inv_dfs['NSW'].columns
# Out:
# Index(['summary', 'items', 'customFields', 'active', 'discountTotal',
#        'importId', 'exportId', 'materialSkuId', 'membershipId', 'paidOn', 'id',
#        'syncStatus', 'budgetCodeId', 'referenceNumber', 'invoiceDate',
#        'dueDate', 'subTotal', 'salesTax', 'salesTaxCode', 'total', 'balance',
#        'invoiceType', 'customer', 'customerAddress', 'location',
#        'locationAddress', 'businessUnit', 'termName', 'createdBy', 'batch',
#        'depositedOn', 'createdOn', 'modifiedOn', 'adjustmentToId', 'job',
#        'projectId', 'royalty', 'employeeInfo', 'commissionEligibilityDate',
#        'sentStatus', 'reviewStatus', 'assignedTo'],
#       dtype='object')
